# %% [markdown]
# ## Irvington Volunteer Project
#
# It's that time of year again!
#
# In your small town of Irvington, there is an annual festival that brings in visitors from all over the state! It's a huge deal and depends completely on the help of the local townspeople.
#
# The festival is 100% volunteer-run and operated, and it's your job to make sure all the volunteers have everything they need to get started. It is also your job to make sure volunteers are well organized, well prepared, and ready to rock when the day of the festival arrives!
#
# In the months before the festival, you collected a lot of information on each of the 1,000 volunteers. This information will help you better organize the volunteer effort. Follow the prompts below to complete your task of leading the volunteer effort!
#
# ***
#
# #### For this task, use the Irvington Volunteers dataset. This dataset includes the following columns:
#
#     * First = First name of volunteer
#     * Last = Last name of volunteer
#     * Gender = Gender of volunteer
#     * Age = Age of volunteer
#     * Shift = Shift of volunteer worker; 1 = first shift; 2 = second shift; 3 = third shift; 4 = forth shift
#     * Month = Month of year volunteer signed up for task
#     * Volunteer Task = Assigned task for volunteer
#     * Task Level = Level of involvement for volunteer task; 1 = beginner, 2 = moderate, 3 = expert
#     * Supervisor Number = Supervisor assigned to volunteer
#     * Fees Owed = Outstanding volunteer fee's that are owed to community
#     * Materials Needed = Does the volunteer still need task-specific materials; Y = yes; N = no
#     * Volunteer Hours = Number of hours volunteer has spent preparing for task
#     * Hours Pledged = Number of hours volunteer pledged to spend on task
#     * Task Training Completed = Did the volunteer complete task-specific training; Y = yes; N = no
#     * Recruited Volunteers = Number of other volunteers recruited by this volunteer

# %% [markdown]
# 1. Import the "Irvington Volunteers" dataset. Check to make sure the dataset looks like what you're expecting

# %%
# importing the libraries

import pandas as pd
import numpy as np

df=pd.read_excel("Irvington_Volunteers.xlsx")
df
# Out:
#         First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson      F   59      4     12              Fire Safety
# 1        Mary  Patterson      F   31      4     10          First Aid Booth
# 2       Tanya      Adams      F   48      1      3         Concession Stand
# 3       Tanya  Henderson      F   19      2      2         Information Desk
# 4      Walter   Franklin      M   25      1      2         Concession Stand
# ..        ...        ...    ...  ...    ...    ...                      ...
# 994    Walter    Mulgrew      M   63      3      4         Information Desk
# 995  Veronica     Looner      F   63      3      5                 Clean Up
# 996     Larry  Patterson      M   49      1      4                 Clean Up
# 997    Victor       Kane      M   39      3      7         Concession Stand
# 998  Victoria     Rogers      F   29      4      4  Gardening and Lawn Care
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 0             2                  1         18                Y
# 1             1                  1          7                N
# 2             3                  1         22                N
# 3             3                  1         26                Y
# 4             1                  1         25                Y
# ..          ...                ...        ...              ...
# 994           2                  5         10                Y
# 995           2                  5         28                N
# 996           2                  5         21                Y
# 997           2                  5         28                Y
# 998           2                  5         21                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 0                 19             28                       Y
# 1                 27             28                       N
# 2                 16             28                       Y
# 3                  9             28                       Y
# 4                 11             28                       Y
# ..               ...            ...                     ...
# 994               25             28                       Y
# 995                8             28                       Y
# 996               16             28                       N
# 997                8             28                       Y
# 998               18             28                       N
#
#      Recruited Volunteers
# 0                       3
# 1                       6
# 2                       2
# 3                       5
# 4                       4
# ..                    ...
# 994                     5
# 995                     4
# 996                     3
# 997                     4
# 998                     1
#
# [999 rows x 15 columns]

# %% [markdown]
# 2. Confirm all your volunteers are accounted for and all of the information you need is within the dataset. What characteristics can you identify in the dataset?
# ***
#
# * How many rows are in the dataset?
# * How many columns are in the dataset?
# * What types of data are within each column?

# %%
df.info()

# There are 999 rows
# There are 15 columns
# There are Integers and strings (objects)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   First                    999 non-null    object
#  1   Last                     999 non-null    object
#  2   Gender                   999 non-null    object
#  3   Age                      999 non-null    int64
#  4   Shift                    999 non-null    int64
#  5   Month                    999 non-null    int64
#  6   Volunteer Task           999 non-null    object
#  7   Task Level               999 non-null    int64
#  8   Supervisor Number        999 non-null    int64
#  9   Fees Owed                999 non-null    int64
#  10  Materials Needed         999 non-null    object
#  11  Volunteer Hours          999 non-null    int64
#  12  Hours Pledged            999 non-null    int64
#  13  Task Training Completed  999 non-null    object
#  14  Recruited Volunteers     999 non-null    int64
# dtypes: int64(9), object(6)
# memory usage: 117.2+ KB

# %% [markdown]
# 3. Before taking this list seriously, we need to check to make sure all the volunteers are eligible to work their specific task. The only eligibility requirement is age-based -- no volunteers can be under the age of 13 and no volunteers can be over the age of 75. Are there any volunteers that fall outside of this range?

# %%
# The minimum age is 16 and the maximum age is 68. 

# There codes options : "Describre" , "loco function, or  "min" and "max" functions

df.describe()
# Out:
#               Age       Shift       Month  Task Level  Supervisor Number  \
# count  999.000000  999.000000  999.000000  999.000000         999.000000
# mean    42.517518    2.506507    6.509510    2.047047           3.026026
# std     15.376030    1.110032    3.452172    0.810001           1.394709
# min     16.000000    1.000000    1.000000    1.000000           1.000000
# 25%     29.000000    2.000000    3.000000    1.000000           2.000000
# 50%     43.000000    3.000000    7.000000    2.000000           3.000000
# 75%     56.000000    3.000000    9.000000    3.000000           4.000000
# max     68.000000    4.000000   12.000000    3.000000           5.000000
#
#         Fees Owed  Volunteer Hours  Hours Pledged  Recruited Volunteers
# count  999.000000       999.000000          999.0            999.000000
# mean    16.272272        19.804805           28.0              3.922923
# std      8.223454         7.978235            0.0              1.527000
# min      2.000000         4.000000           28.0              1.000000
# 25%      9.000000        13.000000           28.0              3.000000
# 50%     16.000000        20.000000           28.0              4.000000
# 75%     23.000000        26.000000           28.0              5.000000
# max     30.000000        36.000000           28.0              7.000000

# %%
print(df["Age"].min())

print(df["Age"].max())

# there are no volunteers taht fall outside the range required, no need to look for  further details
# Out:
# 16
# 68

# %% [markdown]
# 4. Did you miss anyone? Did you make sure to record ALL the information for ALL the volunteers? Quickly check if your missing any data in this dataset.

# %%
# There are no missing data
# - Fisrt option to check : looking at the output/summary from the code "df.info()" above (Q. 3)
# - Second option : using the "isnull().sum()" function below

df.isnull().sum()
# Out:
# First                      0
# Last                       0
# Gender                     0
# Age                        0
# Shift                      0
# Month                      0
# Volunteer Task             0
# Task Level                 0
# Supervisor Number          0
# Fees Owed                  0
# Materials Needed           0
# Volunteer Hours            0
# Hours Pledged              0
# Task Training Completed    0
# Recruited Volunteers       0
# dtype: int64

# %% [markdown]
# 5. A lot of the information we have organizes the volunteers into specific groups. It's important that none of these groups are mismatched (too many people in one group vs another). Let's check how many volunteers fall into each of the following groups. (Hint: you need to use the value counts function for this question).
# ***
#
# * Last (how many volunteers are from the same family?)
# * Gender
# * Shift
# * Month
# * Volunteer Task
# * Task Level
# * Supervisor Number
# * Materials Needed
# * Task Training Completed

# %%
# volunteers from the same family :
df["Last"].value_counts()
# Out:
# Johnson      49
# Carter       39
# Turner       39
# Rose         38
# Michaels     38
# Looner       38
# Kennedy      38
# Henderson    37
# Martins      36
# Davidson     35
# Kane         34
# Moore        34
# Harrison     34
# Walters      34
# Baker        34
# Patterson    33
# Withers      33
# Adams        33
# Vaughn       32
# Sapp         32
# Isaacson     31
# Rogers       31
# Sears        30
# Jackson      29
# Samuelson    29
# Franklin     28
# Gerardo      28
# Mulgrew      26
# Ettienne     25
# Monroe       22
# Name: Last, dtype: int64

# %%
# volunteers from the same Gender :

# %%
# volunteers in the same Shift :
df["Shift"].value_counts(sort=True)
# Out:
# 3    258
# 2    251
# 4    246
# 1    244
# Name: Shift, dtype: int64

# %%
# volunteers in the same month : 
df["Month"].value_counts()
# Out:
# 3     96
# 4     95
# 2     89
# 11    89
# 12    87
# 7     86
# 8     86
# 9     83
# 5     74
# 6     73
# 10    72
# 1     69
# Name: Month, dtype: int64

# %%
# volunteers in the same task : 
df["Volunteer Task"].value_counts()
# Out:
# Concession Stand           142
# Information Desk           131
# First Aid Booth            130
# Clean Up                   128
# Safety                     124
# Fire Safety                120
# Booth Set-Up               114
# Gardening and Lawn Care    110
# Name: Volunteer Task, dtype: int64

# %%
# volunteers in the same task level : 
df["Task Level"].value_counts()
# Out:
# 3    352
# 2    342
# 1    305
# Name: Task Level, dtype: int64

# %%
# volunteers with the same supervisor : 30
df["Supervisor Number"].value_counts()
# Out:
# 3    212
# 2    207
# 5    202
# 4    195
# 1    183
# Name: Supervisor Number, dtype: int64

# %%
# volunteers needing the same material : 30
df["Materials Needed"].value_counts()
# Out:
# Y    637
# N    362
# Name: Materials Needed, dtype: int64

# %%
# volunteers who have completed task training : 30
df["Task Training Completed"].value_counts()
# Out:
# Y    586
# N    413
# Name: Task Training Completed, dtype: int64

# %% [markdown]
# 6. Let's look at these same groups, but from another angle. It's important that the community members are mixing and mingling with members of all ages. What is the average age of volunteers within all the groups listed below? (Hint: you need to use the groupby function for this question). Once you determine the average age of volunteers in the groups below, determine the average number of volunteer hours for all the groups below.
# ***
#
# * Gender
# * Shift
# * Month
# * Volunteer Task
# * Task Level
# * Supervisor Number
# * Materials Needed
# * Task Training Completed

# %%
# Average volunteers AGE by gender
print(df["Age"].groupby(df["Gender"]).mean())
# Out:
# Gender
# F    42.775051
# M    42.270588
# Name: Age, dtype: float64

# %%
# Average volunteers HOURS by gender
print(df["Volunteer Hours"].groupby(df["Gender"]).mean())
# Out:
# Gender
# F    19.932515
# M    19.682353
# Name: Volunteer Hours, dtype: float64

# %%
# Average volunteers age by shift
print(df["Age"].groupby(df["Shift"]).mean())
# Out:
# Shift
# 1    41.434426
# 2    43.334661
# 3    42.275194
# 4    43.012195
# Name: Age, dtype: float64

# %%
# Average volunteers HOURS by shift
print(df["Volunteer Hours"].groupby(df["Shift"]).mean())
# Out:
# Shift
# 1    19.520492
# 2    19.466135
# 3    21.031008
# 4    19.146341
# Name: Volunteer Hours, dtype: float64

# %%
# Average volunteers age by month
print(df["Age"].groupby(df["Month"]).mean())
# Out:
# Month
# 1     46.420290
# 2     41.853933
# 3     41.958333
# 4     44.347368
# 5     40.013514
# 6     37.465753
# 7     40.546512
# 8     42.930233
# 9     43.409639
# 10    43.805556
# 11    41.483146
# 12    45.770115
# Name: Age, dtype: float64

# %%
# Average volunteers HOURS by month
print(df["Volunteer Hours"].groupby(df["Month"]).mean())
# Out:
# Month
# 1     19.869565
# 2     19.764045
# 3     20.906250
# 4     20.757895
# 5     18.932432
# 6     19.767123
# 7     19.837209
# 8     18.744186
# 9     19.506024
# 10    21.541667
# 11    19.000000
# 12    19.000000
# Name: Volunteer Hours, dtype: float64

# %%
# Average volunteers age by task
print(df["Age"].groupby(df["Volunteer Task"]).mean())
# Out:
# Volunteer Task
# Booth Set-Up               40.947368
# Clean Up                   43.648438
# Concession Stand           43.450704
# Fire Safety                43.166667
# First Aid Booth            41.500000
# Gardening and Lawn Care    41.309091
# Information Desk           44.908397
# Safety                     40.709677
# Name: Age, dtype: float64

# %%
    # Average volunteers HOURS by task
print(df["Volunteer Hours"].groupby(df["Volunteer Task"]).mean())
# Out:
# Volunteer Task
# Booth Set-Up               19.640351
# Clean Up                   19.171875
# Concession Stand           20.746479
# Fire Safety                20.058333
# First Aid Booth            19.584615
# Gardening and Lawn Care    19.409091
# Information Desk           19.977099
# Safety                     19.685484
# Name: Volunteer Hours, dtype: float64

# %%
# Average volunteers age by Task level
print(df["Age"].groupby(df["Task Level"]).mean())
# Out:
# Task Level
# 1    43.245902
# 2    42.345029
# 3    42.053977
# Name: Age, dtype: float64

# %%
    # Average volunteers HOURS by Task level
print(df["Volunteer Hours"].groupby(df["Task Level"]).mean())
# Out:
# Task Level
# 1    20.245902
# 2    19.301170
# 3    19.911932
# Name: Volunteer Hours, dtype: float64

# %%
# Average volunteers age by supervisor number
print(df["Age"].groupby(df["Supervisor Number"]).mean())
# Out:
# Supervisor Number
# 1    41.956284
# 2    41.521739
# 3    42.693396
# 4    42.169231
# 5    44.198020
# Name: Age, dtype: float64

# %%
# Average volunteers HOURS by supervisor number
print(df["Volunteer Hours"].groupby(df["Supervisor Number"]).mean())
# Out:
# Supervisor Number
# 1    19.295082
# 2    19.729469
# 3    20.537736
# 4    19.379487
# 5    19.985149
# Name: Volunteer Hours, dtype: float64

# %%
# Average volunteers age by Materials needed
print(df["Age"].groupby(df["Materials Needed"]).mean())
# Out:
# Materials Needed
# N    42.395028
# Y    42.587127
# Name: Age, dtype: float64

# %%
    # Average volunteers HOURS by Materials needed
print(df["Volunteer Hours"].groupby(df["Materials Needed"]).mean())
# Out:
# Materials Needed
# N    20.273481
# Y    19.538462
# Name: Volunteer Hours, dtype: float64

# %%
# Average volunteers age by complteion of the task training
print(df["Age"].groupby(df["Task Training Completed"]).mean())
# Out:
# Task Training Completed
# N    41.268765
# Y    43.397611
# Name: Age, dtype: float64

# %%
    # Average volunteers HOURS by complteion of the task training
print(df["Volunteer Hours"].groupby(df["Task Training Completed"]).mean())
# Out:
# Task Training Completed
# N    19.900726
# Y    19.737201
# Name: Volunteer Hours, dtype: float64

# %% [markdown]
# 7. There are specific groups of volunteers that need to be followed-up with immediately! These are the volunteers that have some outstanding business to handle before the big festival. Locate the group of volunteers that fall within each of these conditions.
# ***
# * Locate the volunteers who still need materials for their volunteer task
# * Locate the volunteers who have not yet completed their volunteer training
# * Locate the volunteers who are experts are their task (aka Task Level = 3)
# * Locate the volunteers who are working fire safety and haven't yet completed their training - these folks need to get trained ASAP!

# %%
# Locate the volunteers who still need materials for their volunteer task

df.loc[df["Materials Needed"]=="Y"]
# Out:
#         First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson      F   59      4     12              Fire Safety
# 3       Tanya  Henderson      F   19      2      2         Information Desk
# 4      Walter   Franklin      M   25      1      2         Concession Stand
# 6      Martin   Ettienne      M   36      2      8  Gardening and Lawn Care
# 8      Denise  Henderson      F   38      1      6          First Aid Booth
# ..        ...        ...    ...  ...    ...    ...                      ...
# 993    Walter    Martins      M   67      3     12              Fire Safety
# 994    Walter    Mulgrew      M   63      3      4         Information Desk
# 996     Larry  Patterson      M   49      1      4                 Clean Up
# 997    Victor       Kane      M   39      3      7         Concession Stand
# 998  Victoria     Rogers      F   29      4      4  Gardening and Lawn Care
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 0             2                  1         18                Y
# 3             3                  1         26                Y
# 4             1                  1         25                Y
# 6             2                  1          8                Y
# 8             2                  1         12                Y
# ..          ...                ...        ...              ...
# 993           1                  5          9                Y
# 994           2                  5         10                Y
# 996           2                  5         21                Y
# 997           2                  5         28                Y
# 998           2                  5         21                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 0                 19             28                       Y
# 3                  9             28                       Y
# 4                 11             28                       Y
# 6                 26             28                       N
# 8                 23             28                       N
# ..               ...            ...                     ...
# 993               28             28                       N
# 994               25             28                       Y
# 996               16             28                       N
# 997                8             28                       Y
# 998               18             28                       N
#
#      Recruited Volunteers
# 0                       3
# 3                       5
# 4                       4
# 6                       6
# 8                       5
# ..                    ...
# 993                     3
# 994                     5
# 996                     3
# 997                     4
# 998                     1
#
# [637 rows x 15 columns]

# %%
# Locate the volunteers who have not yet completed their volunteer training
df.loc[df["Task Training Completed"]=="Y"]
# Out:
#         First       Last Gender  Age  Shift  Month    Volunteer Task  \
# 0      Jackie    Jackson      F   59      4     12       Fire Safety
# 2       Tanya      Adams      F   48      1      3  Concession Stand
# 3       Tanya  Henderson      F   19      2      2  Information Desk
# 4      Walter   Franklin      M   25      1      2  Concession Stand
# 5    Victoria   Ettienne      F   62      4     10       Fire Safety
# ..        ...        ...    ...  ...    ...    ...               ...
# 991      Adam     Turner      M   62      4      3  Concession Stand
# 992      Lisa   Isaacson      F   39      3      2      Booth Set-Up
# 994    Walter    Mulgrew      M   63      3      4  Information Desk
# 995  Veronica     Looner      F   63      3      5          Clean Up
# 997    Victor       Kane      M   39      3      7  Concession Stand
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 0             2                  1         18                Y
# 2             3                  1         22                N
# 3             3                  1         26                Y
# 4             1                  1         25                Y
# 5             2                  1         21                N
# ..          ...                ...        ...              ...
# 991           2                  5         11                N
# 992           1                  5         28                Y
# 994           2                  5         10                Y
# 995           2                  5         28                N
# 997           2                  5         28                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 0                 19             28                       Y
# 2                 16             28                       Y
# 3                  9             28                       Y
# 4                 11             28                       Y
# 5                 17             28                       Y
# ..               ...            ...                     ...
# 991               26             28                       Y
# 992                9             28                       Y
# 994               25             28                       Y
# 995                8             28                       Y
# 997                8             28                       Y
#
#      Recruited Volunteers
# 0                       3
# 2                       2
# 3                       5
# 4                       4
# 5                       2
# ..                    ...
# 991                     3
# 992                     3
# 994                     5
# 995                     4
# 997                     4
#
# [586 rows x 15 columns]

# %%
# Locate the volunteers who are experts are their task (aka Task Level = 3)
df.loc[df["Task Level"]==3]
# Out:
#       First       Last Gender  Age  Shift  Month    Volunteer Task  \
# 2     Tanya      Adams      F   48      1      3  Concession Stand
# 3     Tanya  Henderson      F   19      2      2  Information Desk
# 7     Peter   Michaels      M   36      1      6  Concession Stand
# 10      Sam   Michaels      M   57      4      3   First Aid Booth
# 11     Jada   Walters       F   20      1      5  Concession Stand
# ..      ...        ...    ...  ...    ...    ...               ...
# 980  August    Jackson      F   30      1     11          Clean Up
# 981   Betty     Vaughn      F   65      2      3            Safety
# 982    Mary    Kennedy      F   36      3     11  Information Desk
# 985  Martin    Martins      M   34      2     12  Information Desk
# 988    Mary     Carter      F   60      3      1  Information Desk
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 2             3                  1         22                N
# 3             3                  1         26                Y
# 7             3                  1          7                N
# 10            3                  1          5                Y
# 11            3                  1         26                N
# ..          ...                ...        ...              ...
# 980           3                  5         26                N
# 981           3                  5         28                N
# 982           3                  5         15                Y
# 985           3                  5         21                N
# 988           3                  5         25                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 2                 16             28                       Y
# 3                  9             28                       Y
# 7                 27             28                       N
# 10                32             28                       Y
# 11                10             28                       Y
# ..               ...            ...                     ...
# 980               11             28                       Y
# 981               10             28                       N
# 982               20             28                       N
# 985               13             28                       Y
# 988               10             28                       Y
#
#      Recruited Volunteers
# 2                       2
# 3                       5
# 7                       6
# 10                      3
# 11                      4
# ..                    ...
# 980                     3
# 981                     2
# 982                     5
# 985                     6
# 988                     5
#
# [352 rows x 15 columns]

# %%
# Locate the volunteers who are working fire safety and haven't yet completed their training - these folks need to get trained ASAP!
df.loc[(df["Volunteer Task"]=="Fire Safety")&(df["Task Training Completed"]=="N")]
# Out:
#         First       Last Gender  Age  Shift  Month Volunteer Task  Task Level  \
# 34      Tanya   Harrison      F   44      1      3    Fire Safety           1
# 62    Ronelle  Samuelson      F   55      1      1    Fire Safety           1
# 74      Roger       Sapp      M   67      4      2    Fire Safety           2
# 96       Adam  Patterson      M   23      2      2    Fire Safety           1
# 118    Denise      Moore      F   66      2     10    Fire Safety           2
# 164  Samantha   Franklin      F   61      3      6    Fire Safety           2
# 173    Nicole    Kennedy      F   40      4      5    Fire Safety           1
# 225     Karen     Looner      F   36      3      2    Fire Safety           2
# 227     Betty      Baker      F   17      4      5    Fire Safety           2
# 230      Adam     Vaughn      M   39      4      9    Fire Safety           3
# 231    Martin       Sapp      M   40      1      3    Fire Safety           2
# 250     Aaron      Adams      M   42      3      2    Fire Safety           2
# 254       Sam     Monroe      M   34      2      7    Fire Safety           3
# 273    Nicole   Isaacson      F   57      2      4    Fire Safety           2
# 275     David    Kennedy      M   24      3      6    Fire Safety           3
# 282  Francine       Kane      F   20      4      5    Fire Safety           1
# 303       Tom  Samuelson      M   29      2     12    Fire Safety           1
# 313      Brad     Carter      M   33      4      5    Fire Safety           2
# 323    Oliver       Rose      M   16      1      2    Fire Safety           3
# 345      Mary   Franklin      F   29      4      1    Fire Safety           1
# 361      Jada       Rose      F   35      3      6    Fire Safety           2
# 386     Larry     Monroe      M   65      4      4    Fire Safety           2
# 398      Brad   Harrison      M   54      4     10    Fire Safety           3
# 426     Frank   Walters       M   65      1      3    Fire Safety           2
# 466   Charles      Adams      M   56      1     12    Fire Safety           2
# 485  Veronica    Martins      F   48      3     11    Fire Safety           2
# 489    Martin   Isaacson      M   24      4      9    Fire Safety           1
# 497   Ronelle   Ettienne      F   58      1      4    Fire Safety           2
# 501     Onika   Michaels      F   39      2      4    Fire Safety           3
# 539   Ronelle       Sapp      F   41      1      1    Fire Safety           1
# 547  Francine      Baker      F   17      1      7    Fire Safety           1
# 596     Betty     Rogers      F   17      3      5    Fire Safety           3
# 604     Roger       Kane      M   23      4      1    Fire Safety           1
# 617       Tom      Moore      M   23      4      7    Fire Safety           1
# 621      Lisa     Looner      F   49      3      2    Fire Safety           1
# 627   Ronelle    Withers      F   58      4     10    Fire Safety           1
# 628      Lisa    Johnson      F   52      4      3    Fire Safety           2
# 631     Tanya    Withers      F   16      4      8    Fire Safety           2
# 665     Onika  Samuelson      F   67      1      2    Fire Safety           1
# 720  Francine      Adams      F   41      3     11    Fire Safety           3
# 748      Jada     Looner      F   19      2      6    Fire Safety           2
# 799    Oliver     Vaughn      M   64      2      3    Fire Safety           1
# 845     Tanya  Patterson      F   48      4      8    Fire Safety           1
# 859      John   Harrison      M   31      2      2    Fire Safety           3
# 868  Veronica     Vaughn      F   66      3      8    Fire Safety           3
# 873   Ronelle     Carter      F   49      4      2    Fire Safety           1
# 884    Jackie       Sapp      F   31      4      8    Fire Safety           2
# 892    Victor    Withers      M   61      2     12    Fire Safety           2
# 905    Denise       Sapp      F   68      2      4    Fire Safety           2
# 921      Mike     Carter      M   60      3     10    Fire Safety           1
# 969    Walter    Mulgrew      M   61      3     11    Fire Safety           3
# 993    Walter    Martins      M   67      3     12    Fire Safety           1
#
#      Supervisor Number  Fees Owed Materials Needed  Volunteer Hours  \
# 34                   1         24                N               11
# 62                   1         14                Y               21
# 74                   1          9                Y               25
# 96                   1         29                Y                7
# 118                  1         29                Y                9
# 164                  1         24                Y               12
# 173                  1          6                Y               31
# 225                  2          9                N               27
# 227                  2         30                Y                7
# 230                  2         28                Y                8
# 231                  2         21                Y               16
# 250                  2         16                Y               22
# 254                  2         16                Y               21
# 273                  2         10                N               24
# 275                  2          9                Y               28
# 282                  2         20                Y               15
# 303                  2          8                N               30
# 313                  2         13                N               23
# 323                  2         30                Y                6
# 345                  2         16                N               23
# 361                  2         25                N               14
# 386                  2         18                Y               17
# 398                  3          9                Y               29
# 426                  3         11                N               26
# 466                  3         25                Y               11
# 485                  3         11                N               26
# 489                  3          7                N               29
# 497                  3         10                Y               25
# 501                  3          7                N               31
# 539                  3         12                N               25
# 547                  3         30                Y                5
# 596                  3         22                Y               15
# 604                  4         12                Y               23
# 617                  4         19                N               17
# 621                  4          8                N               28
# 627                  4         10                Y               25
# 628                  4         21                Y               16
# 631                  4         20                N               15
# 665                  4          3                Y               34
# 720                  4          7                Y               31
# 748                  4         28                N               10
# 799                  5          4                Y               33
# 845                  5         14                N               23
# 859                  5         16                Y               19
# 868                  5         14                N               24
# 873                  5         13                Y               24
# 884                  5         20                N               17
# 892                  5         19                Y               19
# 905                  5         29                N                8
# 921                  5         15                N               23
# 969                  5         27                N               12
# 993                  5          9                Y               28
#
#      Hours Pledged Task Training Completed  Recruited Volunteers
# 34              28                       N                     5
# 62              28                       N                     5
# 74              28                       N                     6
# 96              28                       N                     4
# 118             28                       N                     2
# 164             28                       N                     4
# 173             28                       N                     3
# 225             28                       N                     4
# 227             28                       N                     3
# 230             28                       N                     4
# 231             28                       N                     3
# 250             28                       N                     2
# 254             28                       N                     3
# 273             28                       N                     6
# 275             28                       N                     3
# 282             28                       N                     5
# 303             28                       N                     2
# 313             28                       N                     4
# 323             28                       N                     4
# 345             28                       N                     1
# 361             28                       N                     1
# 386             28                       N                     5
# 398             28                       N                     2
# 426             28                       N                     3
# 466             28                       N                     4
# 485             28                       N                     3
# 489             28                       N                     4
# 497             28                       N                     5
# 501             28                       N                     2
# 539             28                       N                     3
# 547             28                       N                     5
# 596             28                       N                     3
# 604             28                       N                     5
# 617             28                       N                     4
# 621             28                       N                     4
# 627             28                       N                     5
# 628             28                       N                     3
# 631             28                       N                     5
# 665             28                       N                     3
# 720             28                       N                     2
# 748             28                       N                     2
# 799             28                       N                     3
# 845             28                       N                     3
# 859             28                       N                     5
# 868             28                       N                     2
# 873             28                       N                     3
# 884             28                       N                     3
# 892             28                       N                     2
# 905             28                       N                     3
# 921             28                       N                     2
# 969             28                       N                     1
# 993             28                       N                     3

# %% [markdown]
# 8. To keep track of volunteers who meet specific conditions, make some additional columns to hold the new information.
# ***
#
# * Inexperienced volunteers may get confused or lost. Create a new column called "needsMentor". This column should be assigned a value of "1" if a volunteer has not completed training and is at skill level 1.
# * How many volunteers haven't completed the volunteer hours they promised they would? Create a new column that subtracts the number of hours pledged ("Hours Pledged") from the number of volunteer hours already worked ("Volunteer Hours). Call this column "hoursNeeded".
# * There are some overly committed volunteers - they have already worked all their pledged volunteer hours and are still going! These folks need to get a specific bonus when the festival is over - we need to track them somehow. Create a new column called "overtimeBonus" - if "hoursNeeded" is less than 0, this column should be "1".

# %%
# Create a new column called "needsMentor".  This column should be assigned a value of "1" if a volunteer has not completed training and is at skill level 1# 


df["NeedMentor"]=np.where(((df["Task Training Completed"]=="N")&(df["Task Level"]==1)), 1,0)
df
# Out:
#         First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson      F   59      4     12              Fire Safety
# 1        Mary  Patterson      F   31      4     10          First Aid Booth
# 2       Tanya      Adams      F   48      1      3         Concession Stand
# 3       Tanya  Henderson      F   19      2      2         Information Desk
# 4      Walter   Franklin      M   25      1      2         Concession Stand
# ..        ...        ...    ...  ...    ...    ...                      ...
# 994    Walter    Mulgrew      M   63      3      4         Information Desk
# 995  Veronica     Looner      F   63      3      5                 Clean Up
# 996     Larry  Patterson      M   49      1      4                 Clean Up
# 997    Victor       Kane      M   39      3      7         Concession Stand
# 998  Victoria     Rogers      F   29      4      4  Gardening and Lawn Care
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 0             2                  1         18                Y
# 1             1                  1          7                N
# 2             3                  1         22                N
# 3             3                  1         26                Y
# 4             1                  1         25                Y
# ..          ...                ...        ...              ...
# 994           2                  5         10                Y
# 995           2                  5         28                N
# 996           2                  5         21                Y
# 997           2                  5         28                Y
# 998           2                  5         21                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 0                 19             28                       Y
# 1                 27             28                       N
# 2                 16             28                       Y
# 3                  9             28                       Y
# 4                 11             28                       Y
# ..               ...            ...                     ...
# 994               25             28                       Y
# 995                8             28                       Y
# 996               16             28                       N
# 997                8             28                       Y
# 998               18             28                       N
#
#      Recruited Volunteers  NeedMentor
# 0                       3           0
# 1                       6           1
# 2                       2           0
# 3                       5           0
# 4                       4           0
# ..                    ...         ...
# 994                     5           0
# 995                     4           0
# 996                     3           0
# 997                     4           0
# 998                     1           0
#
# [999 rows x 16 columns]

# %%
# How many volunteers haven't completed the volunteer hours they promised they would? 
#Create a new column that subtracts the number of hours pledged ("Hours Pledged") from the number of volunteer hours already worked ("Volunteer Hours). 
# Call this column "hoursNeeded"

df["HoursNeeded"]=np.where((df["Hours Pledged"]>df["Volunteer Hours"]), (df["Hours Pledged"]-df["Volunteer Hours"]),(df["Hours Pledged"]-df["Volunteer Hours"]))
df
# Out:
#         First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson      F   59      4     12              Fire Safety
# 1        Mary  Patterson      F   31      4     10          First Aid Booth
# 2       Tanya      Adams      F   48      1      3         Concession Stand
# 3       Tanya  Henderson      F   19      2      2         Information Desk
# 4      Walter   Franklin      M   25      1      2         Concession Stand
# ..        ...        ...    ...  ...    ...    ...                      ...
# 994    Walter    Mulgrew      M   63      3      4         Information Desk
# 995  Veronica     Looner      F   63      3      5                 Clean Up
# 996     Larry  Patterson      M   49      1      4                 Clean Up
# 997    Victor       Kane      M   39      3      7         Concession Stand
# 998  Victoria     Rogers      F   29      4      4  Gardening and Lawn Care
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 0             2                  1         18                Y
# 1             1                  1          7                N
# 2             3                  1         22                N
# 3             3                  1         26                Y
# 4             1                  1         25                Y
# ..          ...                ...        ...              ...
# 994           2                  5         10                Y
# 995           2                  5         28                N
# 996           2                  5         21                Y
# 997           2                  5         28                Y
# 998           2                  5         21                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 0                 19             28                       Y
# 1                 27             28                       N
# 2                 16             28                       Y
# 3                  9             28                       Y
# 4                 11             28                       Y
# ..               ...            ...                     ...
# 994               25             28                       Y
# 995                8             28                       Y
# 996               16             28                       N
# 997                8             28                       Y
# 998               18             28                       N
#
#      Recruited Volunteers  NeedMentor  HoursNeeded
# 0                       3           0            9
# 1                       6           1            1
# 2                       2           0           12
# 3                       5           0           19
# 4                       4           0           17
# ..                    ...         ...          ...
# 994                     5           0            3
# 995                     4           0           20
# 996                     3           0           12
# 997                     4           0           20
# 998                     1           0           10
#
# [999 rows x 17 columns]

# %%
# There are 781 volunteers that haven't completed the  hours they promised they would

df.loc[df["HoursNeeded"]>0]
# Out:
#         First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson      F   59      4     12              Fire Safety
# 1        Mary  Patterson      F   31      4     10          First Aid Booth
# 2       Tanya      Adams      F   48      1      3         Concession Stand
# 3       Tanya  Henderson      F   19      2      2         Information Desk
# 4      Walter   Franklin      M   25      1      2         Concession Stand
# ..        ...        ...    ...  ...    ...    ...                      ...
# 994    Walter    Mulgrew      M   63      3      4         Information Desk
# 995  Veronica     Looner      F   63      3      5                 Clean Up
# 996     Larry  Patterson      M   49      1      4                 Clean Up
# 997    Victor       Kane      M   39      3      7         Concession Stand
# 998  Victoria     Rogers      F   29      4      4  Gardening and Lawn Care
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 0             2                  1         18                Y
# 1             1                  1          7                N
# 2             3                  1         22                N
# 3             3                  1         26                Y
# 4             1                  1         25                Y
# ..          ...                ...        ...              ...
# 994           2                  5         10                Y
# 995           2                  5         28                N
# 996           2                  5         21                Y
# 997           2                  5         28                Y
# 998           2                  5         21                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 0                 19             28                       Y
# 1                 27             28                       N
# 2                 16             28                       Y
# 3                  9             28                       Y
# 4                 11             28                       Y
# ..               ...            ...                     ...
# 994               25             28                       Y
# 995                8             28                       Y
# 996               16             28                       N
# 997                8             28                       Y
# 998               18             28                       N
#
#      Recruited Volunteers  NeedMentor  HoursNeeded
# 0                       3           0            9
# 1                       6           1            1
# 2                       2           0           12
# 3                       5           0           19
# 4                       4           0           17
# ..                    ...         ...          ...
# 994                     5           0            3
# 995                     4           0           20
# 996                     3           0           12
# 997                     4           0           20
# 998                     1           0           10
#
# [781 rows x 17 columns]

# %%
# IGNORE THIS. Another way to check my results (zero value celles vs >0 values ones in the last column)

df.loc[df["HoursNeeded"]==0]
# Out:
#         First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 17      Roger     Looner      M   51      1     10  Gardening and Lawn Care
# 28      Carla   Franklin      F   60      1      4          First Aid Booth
# 86   Francine     Monroe      F   43      4      4         Concession Stand
# 103      Adam     Vaughn      M   30      3      5             Booth Set-Up
# 117     Carla       Rose      F   55      4     12  Gardening and Lawn Care
# 166     Paula      Moore      F   60      3      4                 Clean Up
# 275     David    Kennedy      M   24      3      6              Fire Safety
# 295     india      Adams      F   49      1      3         Concession Stand
# 308    Victor   Davidson      M   33      1      7                 Clean Up
# 319     Paula     Looner      F   52      3      7         Concession Stand
# 402    Harold     Turner      M   57      4      3         Concession Stand
# 409      Lisa   Harrison      F   30      2      6             Booth Set-Up
# 411      Jada    Jackson      F   32      3      7          First Aid Booth
# 431      Brad    Withers      M   60      2     12                   Safety
# 448       Sam    Kennedy      M   18      1      6                   Safety
# 473     india  Patterson      F   26      2     11         Concession Stand
# 553    Victor   Davidson      M   63      1      2         Concession Stand
# 562     india      Baker      F   55      2     10         Information Desk
# 571     india    Martins      F   51      3      3                   Safety
# 580     Aaron    Jackson      M   50      1      1                   Safety
# 621      Lisa     Looner      F   49      3      2              Fire Safety
# 633  Samantha     Vaughn      F   46      2     11              Fire Safety
# 641      Adam   Isaacson      M   37      3      6                 Clean Up
# 657      Jack      Moore      M   26      4      6         Concession Stand
# 682    Walter     Turner      M   63      3      1         Concession Stand
# 794      Lisa       Rose      F   37      3      2         Concession Stand
# 803    Oliver    Martins      M   22      1     12          First Aid Booth
# 804       Tom   Davidson      M   18      2      4                 Clean Up
# 847     Paula      Sears      F   38      4      5          First Aid Booth
# 848     Onika    Gerardo      F   45      1      9          First Aid Booth
# 882  Victoria      Moore      F   56      3      3  Gardening and Lawn Care
# 962    Martin    Withers      M   46      4      7          First Aid Booth
# 967    Harold     Carter      M   27      1     11         Information Desk
# 993    Walter    Martins      M   67      3     12              Fire Safety
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 17            3                  1          9                N
# 28            1                  1          9                N
# 86            1                  1          7                Y
# 103           2                  1         10                N
# 117           1                  1          8                Y
# 166           1                  1          6                Y
# 275           3                  2          9                Y
# 295           3                  2         10                Y
# 308           3                  2          8                Y
# 319           3                  2          8                N
# 402           2                  3          8                Y
# 409           3                  3          8                N
# 411           3                  3          9                Y
# 431           1                  3          5                N
# 448           3                  3          8                Y
# 473           2                  3          7                N
# 553           1                  3          7                N
# 562           1                  3          8                Y
# 571           1                  3         10                Y
# 580           1                  3         10                Y
# 621           1                  4          8                N
# 633           1                  4          7                Y
# 641           3                  4          8                N
# 657           3                  4          6                N
# 682           1                  4          8                Y
# 794           2                  4         10                Y
# 803           1                  5          9                Y
# 804           3                  5          5                N
# 847           3                  5          5                Y
# 848           3                  5          9                N
# 882           1                  5          7                Y
# 962           3                  5          6                Y
# 967           2                  5          9                Y
# 993           1                  5          9                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 17                28             28                       Y
# 28                28             28                       Y
# 86                28             28                       Y
# 103               28             28                       Y
# 117               28             28                       Y
# 166               28             28                       Y
# 275               28             28                       N
# 295               28             28                       N
# 308               28             28                       N
# 319               28             28                       N
# 402               28             28                       Y
# 409               28             28                       Y
# 411               28             28                       Y
# 431               28             28                       Y
# 448               28             28                       Y
# 473               28             28                       N
# 553               28             28                       N
# 562               28             28                       Y
# 571               28             28                       Y
# 580               28             28                       N
# 621               28             28                       N
# 633               28             28                       Y
# 641               28             28                       Y
# 657               28             28                       N
# 682               28             28                       Y
# 794               28             28                       Y
# 803               28             28                       Y
# 804               28             28                       Y
# 847               28             28                       Y
# 848               28             28                       Y
# 882               28             28                       N
# 962               28             28                       N
# 967               28             28                       Y
# 993               28             28                       N
#
#      Recruited Volunteers  NeedMentor  HoursNeeded
# 17                      3           0            0
# 28                      3           0            0
# 86                      5           0            0
# 103                     2           0            0
# 117                     4           0            0
# 166                     6           0            0
# 275                     3           0            0
# 295                     2           0            0
# 308                     4           0            0
# 319                     4           0            0
# 402                     4           0            0
# 409                     4           0            0
# 411                     3           0            0
# 431                     7           0            0
# 448                     4           0            0
# 473                     5           0            0
# 553                     5           1            0
# 562                     4           0            0
# 571                     2           0            0
# 580                     2           1            0
# 621                     4           1            0
# 633                     5           0            0
# 641                     4           0            0
# 657                     6           0            0
# 682                     4           0            0
# 794                     2           0            0
# 803                     3           0            0
# 804                     7           0            0
# 847                     7           0            0
# 848                     3           0            0
# 882                     5           1            0
# 962                     6           0            0
# 967                     3           0            0
# 993                     3           1            0

# %%
# IGNORE THIS. Another way to check my results

df["HoursNeeded"].value_counts(sort=True)
# Out:
#  3     50
#  12    48
# -1     47
#  19    42
#  10    41
#  15    41
#  6     39
#  16    37
# -3     37
#  14    37
#  5     36
#  9     36
#  2     35
#  4     35
#  17    34
#  18    34
#  0     34
#  13    32
#  11    32
# -2     32
#  1     31
#  20    31
#  8     31
#  7     29
# -4     25
#  21    23
# -5     20
# -6     15
#  22    15
#  23    11
# -7      6
# -8      2
#  24     1
# Name: HoursNeeded, dtype: int64

# %%
# IGNORE THIS. Another way to check my results

df.describe()
# Out:
#               Age       Shift       Month  Task Level  Supervisor Number  \
# count  999.000000  999.000000  999.000000  999.000000         999.000000
# mean    42.517518    2.506507    6.509510    2.047047           3.026026
# std     15.376030    1.110032    3.452172    0.810001           1.394709
# min     16.000000    1.000000    1.000000    1.000000           1.000000
# 25%     29.000000    2.000000    3.000000    1.000000           2.000000
# 50%     43.000000    3.000000    7.000000    2.000000           3.000000
# 75%     56.000000    3.000000    9.000000    3.000000           4.000000
# max     68.000000    4.000000   12.000000    3.000000           5.000000
#
#         Fees Owed  Volunteer Hours  Hours Pledged  Recruited Volunteers  \
# count  999.000000       999.000000          999.0            999.000000
# mean    16.272272        19.804805           28.0              3.922923
# std      8.223454         7.978235            0.0              1.527000
# min      2.000000         4.000000           28.0              1.000000
# 25%      9.000000        13.000000           28.0              3.000000
# 50%     16.000000        20.000000           28.0              4.000000
# 75%     23.000000        26.000000           28.0              5.000000
# max     30.000000        36.000000           28.0              7.000000
#
#        NeedMentor  HoursNeeded
# count  999.000000   999.000000
# mean     0.119119     8.195195
# std      0.324091     7.978235
# min      0.000000    -8.000000
# 25%      0.000000     2.000000
# 50%      0.000000     8.000000
# 75%      0.000000    15.000000
# max      1.000000    24.000000

# %%
# IGNORE THIS. Another way to check my results

filtr=df["HoursNeeded"]==0
filtr.sum()
# Out:
# 34

# %%
# There are some overly committed volunteers - they have already worked all their pledged volunteer hours and are still going! 
#These folks need to get a specific bonus when the festival is over - we need to track them somehow. Create a new column called "overtimeBonus" - 
# if "hoursNeeded" is less than 0, this column should be "1". 

df["OvertimeBonus"]=np.where((df["HoursNeeded"]<0), 1,0)
df
df.loc[df["OvertimeBonus"]==1]

# There are 184 volunteers that exceeded they pledged hours
# Out:
#       First       Last Gender  Age  Shift  Month    Volunteer Task  \
# 10      Sam   Michaels      M   57      4      3   First Aid Booth
# 16     John     Looner      M   21      3      4          Clean Up
# 18    Karen     Looner      F   32      2      9      Booth Set-Up
# 20   Victor     Looner      M   22      3      4          Clean Up
# 21    Frank  Patterson      M   43      3      2  Concession Stand
# ..      ...        ...    ...  ...    ...    ...               ...
# 960   Onika   Michaels      F   62      1      7            Safety
# 963   Aaron  Patterson      M   21      2      8            Safety
# 964  August    Martins      F   62      2      7  Information Desk
# 989   Onika      Sears      F   38      1      1  Concession Stand
# 990     Sam  Samuelson      M   36      1      9          Clean Up
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 10            3                  1          5                Y
# 16            1                  1          8                N
# 18            3                  1          9                Y
# 20            2                  1          2                Y
# 21            3                  1          5                Y
# ..          ...                ...        ...              ...
# 960           3                  5          8                Y
# 963           1                  5          4                N
# 964           2                  5          6                Y
# 989           1                  5          3                N
# 990           1                  5          7                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 10                32             28                       Y
# 16                30             28                       Y
# 18                29             28                       Y
# 20                32             28                       Y
# 21                32             28                       Y
# ..               ...            ...                     ...
# 960               29             28                       Y
# 963               32             28                       N
# 964               29             28                       N
# 989               34             28                       N
# 990               30             28                       Y
#
#      Recruited Volunteers  NeedMentor  HoursNeeded  OvertimeBonus
# 10                      3           0           -4              1
# 16                      2           0           -2              1
# 18                      2           0           -1              1
# 20                      6           0           -4              1
# 21                      3           0           -4              1
# ..                    ...         ...          ...            ...
# 960                     3           0           -1              1
# 963                     4           1           -4              1
# 964                     5           0           -1              1
# 989                     3           1           -6              1
# 990                     3           0           -2              1
#
# [184 rows x 18 columns]

# %% [markdown]
# 9. The Mayor wants to make a speech about the different types of community members that are volunteering for the festival. Specifically, the Mayor would like to present some information on the different age groups. Create a new column called "Age Group" and bin the "Age" column to create bins based on the age of the volunteer. Follow the guidance below for the variations in age. (Hint: you can use any code you like to complete this task - np.select is also an option!)
# ***
#
# * Teen (0 - 17)
# * Young Adult (17.1 - 35)
# * Adult (35.1 - 65)
# * Senior (65+)

# %%
# Create a new column called "Age Group" and bin the "Age" column to create bins based on the age of the volunteer. 

bins_limits_irv=[0,17,35,65,150]
bins_labels_irv=["Teen","Young Adult","Adult","Senior"]

#df["Age Group"]

df["Age Group"] = pd.cut(df["Age"], bins_limits_irv, labels = bins_labels_irv)
df
# Out:
#         First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson      F   59      4     12              Fire Safety
# 1        Mary  Patterson      F   31      4     10          First Aid Booth
# 2       Tanya      Adams      F   48      1      3         Concession Stand
# 3       Tanya  Henderson      F   19      2      2         Information Desk
# 4      Walter   Franklin      M   25      1      2         Concession Stand
# ..        ...        ...    ...  ...    ...    ...                      ...
# 994    Walter    Mulgrew      M   63      3      4         Information Desk
# 995  Veronica     Looner      F   63      3      5                 Clean Up
# 996     Larry  Patterson      M   49      1      4                 Clean Up
# 997    Victor       Kane      M   39      3      7         Concession Stand
# 998  Victoria     Rogers      F   29      4      4  Gardening and Lawn Care
#
#      Task Level  Supervisor Number  Fees Owed Materials Needed  \
# 0             2                  1         18                Y
# 1             1                  1          7                N
# 2             3                  1         22                N
# 3             3                  1         26                Y
# 4             1                  1         25                Y
# ..          ...                ...        ...              ...
# 994           2                  5         10                Y
# 995           2                  5         28                N
# 996           2                  5         21                Y
# 997           2                  5         28                Y
# 998           2                  5         21                Y
#
#      Volunteer Hours  Hours Pledged Task Training Completed  \
# 0                 19             28                       Y
# 1                 27             28                       N
# 2                 16             28                       Y
# 3                  9             28                       Y
# 4                 11             28                       Y
# ..               ...            ...                     ...
# 994               25             28                       Y
# 995                8             28                       Y
# 996               16             28                       N
# 997                8             28                       Y
# 998               18             28                       N
#
#      Recruited Volunteers  NeedMentor  HoursNeeded  OvertimeBonus    Age Group
# 0                       3           0            9              0        Adult
# 1                       6           1            1              0  Young Adult
# 2                       2           0           12              0        Adult
# 3                       5           0           19              0  Young Adult
# 4                       4           0           17              0  Young Adult
# ..                    ...         ...          ...            ...          ...
# 994                     5           0            3              0        Adult
# 995                     4           0           20              0        Adult
# 996                     3           0           12              0        Adult
# 997                     4           0           20              0        Adult
# 998                     1           0           10              0  Young Adult
#
# [999 rows x 19 columns]

# %%
df["Age Group"].value_counts()
# Out:
# Adult          580
# Young Adult    317
# Senior          61
# Teen            41
# Name: Age Group, dtype: int64

# %% [markdown]
# 10. The Supervisor Number column is all messed up. Someone didn't record is correctly, and now it is meaningless! Drop it from this dataset - it's not providing any meaningful information.

# %%
# Droppimg the Supervisor number from the dataset

df.drop(columns="Supervisor Number", inplace=True)
df
# Out:
#         First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson      F   59      4     12              Fire Safety
# 1        Mary  Patterson      F   31      4     10          First Aid Booth
# 2       Tanya      Adams      F   48      1      3         Concession Stand
# 3       Tanya  Henderson      F   19      2      2         Information Desk
# 4      Walter   Franklin      M   25      1      2         Concession Stand
# ..        ...        ...    ...  ...    ...    ...                      ...
# 994    Walter    Mulgrew      M   63      3      4         Information Desk
# 995  Veronica     Looner      F   63      3      5                 Clean Up
# 996     Larry  Patterson      M   49      1      4                 Clean Up
# 997    Victor       Kane      M   39      3      7         Concession Stand
# 998  Victoria     Rogers      F   29      4      4  Gardening and Lawn Care
#
#      Task Level  Fees Owed Materials Needed  Volunteer Hours  Hours Pledged  \
# 0             2         18                Y               19             28
# 1             1          7                N               27             28
# 2             3         22                N               16             28
# 3             3         26                Y                9             28
# 4             1         25                Y               11             28
# ..          ...        ...              ...              ...            ...
# 994           2         10                Y               25             28
# 995           2         28                N                8             28
# 996           2         21                Y               16             28
# 997           2         28                Y                8             28
# 998           2         21                Y               18             28
#
#     Task Training Completed  Recruited Volunteers  NeedMentor  HoursNeeded  \
# 0                         Y                     3           0            9
# 1                         N                     6           1            1
# 2                         Y                     2           0           12
# 3                         Y                     5           0           19
# 4                         Y                     4           0           17
# ..                      ...                   ...         ...          ...
# 994                       Y                     5           0            3
# 995                       Y                     4           0           20
# 996                       N                     3           0           12
# 997                       Y                     4           0           20
# 998                       N                     1           0           10
#
#      OvertimeBonus    Age Group
# 0                0        Adult
# 1                0  Young Adult
# 2                0        Adult
# 3                0  Young Adult
# 4                0  Young Adult
# ..             ...          ...
# 994              0        Adult
# 995              0        Adult
# 996              0        Adult
# 997              0        Adult
# 998              0  Young Adult
#
# [999 rows x 18 columns]

# %% [markdown]
# 11. There is a new policy about volunteer fees. It seems that some of the fees owed were actually for materials that the volunteer paid for out of pocket. Wipe out the debt for those volunteers who owe just a few dollars. If the volunteer owes less than 5 dollars, replace that value with 0!

# %%
# If the volunteer owes less than 5 dollars, replace that value with 0!

df.loc[df["Fees Owed"]<5,"Fees Owed"]=0
df
df.loc[df["Fees Owed"]<5]

# There are 84 volunteers that owed less than 5 dollars
# Out:
#        First       Last Gender  Age  Shift  Month           Volunteer Task  \
# 20    Victor     Looner      M   22      3      4                 Clean Up
# 22     Roger       Sapp      M   22      4     12                 Clean Up
# 35       Tom     Vaughn      M   24      3     12         Information Desk
# 39     Frank       Sapp      M   51      3      7         Information Desk
# 46   Charles   Walters       M   60      2      8                 Clean Up
# ..       ...        ...    ...  ...    ...    ...                      ...
# 949      Sam       Kane      M   38      2     10              Fire Safety
# 951    Peter   Franklin      M   40      4      7  Gardening and Lawn Care
# 953     Mike  Henderson      M   61      2      4         Information Desk
# 963    Aaron  Patterson      M   21      2      8                   Safety
# 989    Onika      Sears      F   38      1      1         Concession Stand
#
#      Task Level  Fees Owed Materials Needed  Volunteer Hours  Hours Pledged  \
# 20            2          0                Y               32             28
# 22            3          0                Y               31             28
# 35            2          0                Y               30             28
# 39            1          0                N               33             28
# 46            1          0                Y               33             28
# ..          ...        ...              ...              ...            ...
# 949           1          0                N               31             28
# 951           3          0                Y               35             28
# 953           3          0                N               32             28
# 963           1          0                N               32             28
# 989           1          0                N               34             28
#
#     Task Training Completed  Recruited Volunteers  NeedMentor  HoursNeeded  \
# 20                        Y                     6           0           -4
# 22                        Y                     6           0           -3
# 35                        N                     6           0           -2
# 39                        Y                     3           0           -5
# 46                        N                     4           1           -5
# ..                      ...                   ...         ...          ...
# 949                       Y                     6           0           -3
# 951                       Y                     3           0           -7
# 953                       Y                     6           0           -4
# 963                       N                     4           1           -4
# 989                       N                     3           1           -6
#
#      OvertimeBonus    Age Group
# 20               1  Young Adult
# 22               1  Young Adult
# 35               1  Young Adult
# 39               1        Adult
# 46               1        Adult
# ..             ...          ...
# 949              1        Adult
# 951              1        Adult
# 953              1        Adult
# 963              1  Young Adult
# 989              1        Adult
#
# [84 rows x 18 columns]

# %% [markdown]
# 12. We need some code that we can keep around for next year -- when we have the same task but new data! Define a few functions that can complete tasks that we will need to repeat down the road.
#
# ***
#
# * Define a function to recode the column "Gender". Instead of "M" and "F" -- have the words spelled out "Male" and "Female". Apply this function to the "Gender" column.
# * Define a function to recode the column "Month". Convert the numeric "Month" to the name of the Month. Apply this function to the column "Month" and create a new column called "Name of Month".

# %%
def gender_long(x):
    if x=="M":
        return "Male"
    elif x=="F":
        return "Female"
    elif x=="":
        return  "unknown"    
    else:
        return "other"
    

df["Gender"]=df["Gender"].apply(gender_long)   


# note to myself : if this code is run more than once, it returns "other" the second time instead of the gender, because the new input 
   # is no longer "M or ". To avoid that, either make sure to run it only once, or add the 2 conditions below :
    
#    elif x=="Male":
     #   return "Male"
    #elif x=="Female":
    #    return "Female"

# %%
df
# Out:
#         First       Last  Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson  Female   59      4     12              Fire Safety
# 1        Mary  Patterson  Female   31      4     10          First Aid Booth
# 2       Tanya      Adams  Female   48      1      3         Concession Stand
# 3       Tanya  Henderson  Female   19      2      2         Information Desk
# 4      Walter   Franklin    Male   25      1      2         Concession Stand
# ..        ...        ...     ...  ...    ...    ...                      ...
# 994    Walter    Mulgrew    Male   63      3      4         Information Desk
# 995  Veronica     Looner  Female   63      3      5                 Clean Up
# 996     Larry  Patterson    Male   49      1      4                 Clean Up
# 997    Victor       Kane    Male   39      3      7         Concession Stand
# 998  Victoria     Rogers  Female   29      4      4  Gardening and Lawn Care
#
#      Task Level  Fees Owed Materials Needed  Volunteer Hours  Hours Pledged  \
# 0             2         18                Y               19             28
# 1             1          7                N               27             28
# 2             3         22                N               16             28
# 3             3         26                Y                9             28
# 4             1         25                Y               11             28
# ..          ...        ...              ...              ...            ...
# 994           2         10                Y               25             28
# 995           2         28                N                8             28
# 996           2         21                Y               16             28
# 997           2         28                Y                8             28
# 998           2         21                Y               18             28
#
#     Task Training Completed  Recruited Volunteers  NeedMentor  HoursNeeded  \
# 0                         Y                     3           0            9
# 1                         N                     6           1            1
# 2                         Y                     2           0           12
# 3                         Y                     5           0           19
# 4                         Y                     4           0           17
# ..                      ...                   ...         ...          ...
# 994                       Y                     5           0            3
# 995                       Y                     4           0           20
# 996                       N                     3           0           12
# 997                       Y                     4           0           20
# 998                       N                     1           0           10
#
#      OvertimeBonus    Age Group
# 0                0        Adult
# 1                0  Young Adult
# 2                0        Adult
# 3                0  Young Adult
# 4                0  Young Adult
# ..             ...          ...
# 994              0        Adult
# 995              0        Adult
# 996              0        Adult
# 997              0        Adult
# 998              0  Young Adult
#
# [999 rows x 18 columns]

# %%
# Define a function to recode the column "Month". Convert the numeric "Month" to the name of the Month. 
# Apply this function to the column "Month" and create a new column called "Name of Month".

# %%
def month_long(x):
    month_nbr=[1,2,3,4,5,6,7,89,10,11,12]
    month_ltr=["january", "february", "march", "april", "may", "june", "july", "august", "september", "october", "november", "december"]
    if x==1:
        return "january"
    elif x==2:
        return "february"    
    elif x==3:
        return "march"
    elif x==4:
        return "april"
    elif x==5:
        return "may"
    elif x==6:
        return "june"
    elif x==7:
        return "july"
    elif x==8:
        return "august"
    elif x==9:
        return "september"
    elif x==10:
        return "october"
    elif x==11:
        return "november"
    elif x==12:
        return "december"
    else:
        return "other"
    
df["Name of Month"]=df["Month"].apply(month_long)

# %%
df
# Out:
#         First       Last  Gender  Age  Shift  Month           Volunteer Task  \
# 0      Jackie    Jackson  Female   59      4     12              Fire Safety
# 1        Mary  Patterson  Female   31      4     10          First Aid Booth
# 2       Tanya      Adams  Female   48      1      3         Concession Stand
# 3       Tanya  Henderson  Female   19      2      2         Information Desk
# 4      Walter   Franklin    Male   25      1      2         Concession Stand
# ..        ...        ...     ...  ...    ...    ...                      ...
# 994    Walter    Mulgrew    Male   63      3      4         Information Desk
# 995  Veronica     Looner  Female   63      3      5                 Clean Up
# 996     Larry  Patterson    Male   49      1      4                 Clean Up
# 997    Victor       Kane    Male   39      3      7         Concession Stand
# 998  Victoria     Rogers  Female   29      4      4  Gardening and Lawn Care
#
#      Task Level  Fees Owed Materials Needed  Volunteer Hours  Hours Pledged  \
# 0             2         18                Y               19             28
# 1             1          7                N               27             28
# 2             3         22                N               16             28
# 3             3         26                Y                9             28
# 4             1         25                Y               11             28
# ..          ...        ...              ...              ...            ...
# 994           2         10                Y               25             28
# 995           2         28                N                8             28
# 996           2         21                Y               16             28
# 997           2         28                Y                8             28
# 998           2         21                Y               18             28
#
#     Task Training Completed  Recruited Volunteers  NeedMentor  HoursNeeded  \
# 0                         Y                     3           0            9
# 1                         N                     6           1            1
# 2                         Y                     2           0           12
# 3                         Y                     5           0           19
# 4                         Y                     4           0           17
# ..                      ...                   ...         ...          ...
# 994                       Y                     5           0            3
# 995                       Y                     4           0           20
# 996                       N                     3           0           12
# 997                       Y                     4           0           20
# 998                       N                     1           0           10
#
#      OvertimeBonus    Age Group Name of Month
# 0                0        Adult      december
# 1                0  Young Adult       october
# 2                0        Adult         march
# 3                0  Young Adult      february
# 4                0  Young Adult      february
# ..             ...          ...           ...
# 994              0        Adult         april
# 995              0        Adult           may
# 996              0        Adult         april
# 997              0        Adult          july
# 998              0  Young Adult         april
#
# [999 rows x 19 columns]

# %%
## lsts code is long, have to look for a way to make it shorter
